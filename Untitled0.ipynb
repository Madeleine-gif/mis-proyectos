# %% [markdown]
# <a href="https://colab.research.google.com/github/Madeleine-gif/mis-proyectos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("¡Mi primera prueba en la nube!")
# Out:
# ¡Mi primera prueba en la nube!
